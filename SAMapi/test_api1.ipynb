# %%
import requests
import json
from pathlib import Path

DOMAIN = 'http://127.0.0.1:8080' #解决ssl问题，不要s

try:
    response = requests.get(DOMAIN, timeout=10)  # 默认超时时间为 10 秒
except requests.exceptions.ConnectionError as e:
    print(f"请求错误：{e}")


def get_completion(image_path:str|Path, url=DOMAIN):
    headers = {'Content-Type': 'application/json'}
    data = {"image_path": image_path}
    try:
        response = requests.get(url=url, data=json.dumps(data), headers=headers, verify=False)
        print(f"response:{response}")
        
        if response is not None and response.status_code == 200:
            try:
                response_data = response.json()
                print(f"response_data:{response_data}")
                image_url = response_data.get('response').get('image_url')
                
                if image_url:
                    print(f"图片URL: {image_url}")
                    return image_url
                else:
                    print("响应中未找到图片URL") 
                    return None
            except json.JSONDecodeError as e:
                print(f"JSON解析错误: {e}")
                return None
        else:
            print(f"请求失败，状态码: {response.status_code}")
            return None
    except requests.RequestException as e:
        print(f"请求错误: {e}")
        return None

    # return json.dumps({"response": response})


# 测试 print_response 函数
# 确保了print_response函数能够正确地打印出解析后的JSON数据，并且在调用函数后增加了异常处理逻辑来避免因解析错误而导致程序崩溃。


def get_prompt_response(prompt):
    # 这里假设 get_completion 函数从某个API获取数据并返回
    # 返回的结果应该是一个包含 'response' 键的字典

    # 假设这是从外部API获取的数据
    response = prompt

    # 正确的返回方式应该是这样的
    return json.dumps({"response": response})

def print_response(prompt):
    try:
        result = get_completion(prompt)
        print(f"result:{result}")
        # parsed_result = json.loads(result)
        # print(parsed_result['response'])
    except json.JSONDecodeError as e:
        print(f"JSON 解析错误: {e}")
        # 处理错误情况，例如打印原始返回值
        print("原始返回值:", result)

print_response('./SAM-Med2D/data_demo/images/amos_0507_31.png')
# Out:
# response:<Response [200]>
# response_data:{'image_url': 'http://127.0.0.1:8080/processed/seg_829a0513-9f0f-4a01-918a-9168abb67f6a.png', 'status': 200, 'time': '2024-09-24 13:14:37'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 70
#      67         # 处理错误情况，例如打印原始返回值
#      68         print("原始返回值:", result)
# ---> 70 print_response('./SAM-Med2D/data_demo/images/amos_0507_31.png')
#
# Cell In[2], line 61, in print_response(prompt)
#      59 def print_response(prompt):
#      60     try:
# ---> 61         result = get_completion(prompt)
#      62         print(f"result:{result}")
#      63         # parsed_result = json.loads(result)
#      64         # print(parsed_result['response'])
#
# Cell In[2], line 24, in get_completion(image_path, url)
#      22 response_data = response.json()
#      23 print(f"response_data:{response_data}")
# ...

# %%
import requests
import json
from pathlib import Path


try:
    response = requests.get('https://127.0.0.1:8080', timeout=10)  # 默认超时时间为 10 秒
except requests.exceptions.ConnectionError as e:
    print(f"请求错误：{e}")


def get_completion(image_path:str|Path, url='https://127.0.0.1:8080'):
    headers = {'Content-Type': 'application/json'}
    data = {"image_path": image_path}
    try:
        response = requests.get(url=url, data=json.dumps(data), headers=headers)
        print(f"response:{response}")
        
        if response is not None and response.status_code == 200:
            try:
                response_data = response.json()
                print(f"response_data:{response_data}")
                image_url = response_data.get('response').get('image_url')
                
                if image_url:
                    print(f"图片URL: {image_url}")
                    return image_url
                else:
                    print("响应中未找到图片URL") 
                    return None
            except json.JSONDecodeError as e:
                print(f"JSON解析错误: {e}")
                return None
        else:
            print(f"请求失败，状态码: {response.status_code}")
            return None
    except requests.RequestException as e:
        print(f"请求错误: {e}")
        return None

    # return json.dumps({"response": response})


# 测试 print_response 函数
# 确保了print_response函数能够正确地打印出解析后的JSON数据，并且在调用函数后增加了异常处理逻辑来避免因解析错误而导致程序崩溃。


def get_prompt_response(prompt):
    # 这里假设 get_completion 函数从某个API获取数据并返回
    # 返回的结果应该是一个包含 'response' 键的字典

    # 假设这是从外部API获取的数据
    response = prompt

    # 正确的返回方式应该是这样的
    return json.dumps({"response": response})

def print_response(prompt):
    try:
        result = get_completion(prompt)
        print(f"result:{result}")
        parsed_result = json.loads(result)
        print(parsed_result['response'])
    except json.JSONDecodeError as e:
        print(f"JSON 解析错误: {e}")
        # 处理错误情况，例如打印原始返回值
        print("原始返回值:", result)

print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
# Out:
# 请求错误：HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# 请求错误: HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# result:None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 69
#      66         # 处理错误情况，例如打印原始返回值
#      67         print("原始返回值:", result)
# ---> 69 print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
#
# Cell In[4], line 62, in print_response(prompt)
#      60     result = get_completion(prompt)
#      61     print(f"result:{result}")
# ---> 62     parsed_result = json.loads(result)
#      63     print(parsed_result['response'])
#      64 except json.JSONDecodeError as e:
#
# ...

# %%
import requests
import json
from pathlib import Path


try:
    response = requests.get('https://127.0.0.1:8080', timeout=10)  # 默认超时时间为 10 秒
except requests.exceptions.ConnectionError as e:
    print(f"请求错误：{e}")


def get_completion(image_path:str|Path, url='https://127.0.0.1:8080'):
    headers = {'Content-Type': 'application/json'}
    data = {"image_path": image_path}
    try:
        response = requests.get(url=url, data=json.dumps(data), headers=headers)
        print(f"response:{response}")
        
        if response is not None and response.status_code == 200:
            try:
                response_data = response.json()
                print(f"response_data:{response_data}")
                image_url = response_data.get('response').get('image_url')
                
                if image_url:
                    print(f"图片URL: {image_url}")
                    return image_url
                else:
                    print("响应中未找到图片URL") 
                    return None
            except json.JSONDecodeError as e:
                print(f"JSON解析错误: {e}")
                return None
        else:
            print(f"请求失败，状态码: {response.status_code}")
            return None
    except requests.RequestException as e:
        print(f"请求错误: {e}")
        return None

    # return json.dumps({"response": response})


# 测试 print_response 函数
# 确保了print_response函数能够正确地打印出解析后的JSON数据，并且在调用函数后增加了异常处理逻辑来避免因解析错误而导致程序崩溃。


def get_prompt_response(prompt):
    # 这里假设 get_completion 函数从某个API获取数据并返回
    # 返回的结果应该是一个包含 'response' 键的字典

    # 假设这是从外部API获取的数据
    response = prompt

    # 正确的返回方式应该是这样的
    return json.dumps({"response": response})

def print_response(prompt):
    try:
        result = get_completion(prompt)
        print(f"result:{result}")
        parsed_result = json.loads(result)
        print(parsed_result['response'])
    except json.JSONDecodeError as e:
        print(f"JSON 解析错误: {e}")
        # 处理错误情况，例如打印原始返回值
        print("原始返回值:", result)

print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
# Out:
# 请求错误：HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# 请求错误: HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# result:None
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[13], line 69
#
#      66         # 处理错误情况，例如打印原始返回值
#
#      67         print("原始返回值:", result)
#
# ---> 69 print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
#
#
#
# Cell In[13], line 62, in print_response(prompt)
#
#      60     result = get_completion(prompt)
#
#      61     print(f"result:{result}")
#
# ---> 62     parsed_result = json.loads(result)
#
#      63     print(parsed_result['response'])
#
#      64 except json.JSONDecodeError as e:
#
#
#
# ...

# %%
import requests
import json
from pathlib import Path


try:
    response = requests.get('https://127.0.0.1:8080', timeout=10)  # 默认超时时间为 10 秒
except requests.exceptions.ConnectionError as e:
    print(f"请求错误：{e}")


def get_completion(image_path:str|Path, url='https://127.0.0.1:8080'):
    headers = {'Content-Type': 'application/json'}
    data = {"image_path": image_path}
    try:
        response = requests.get(url=url, data=json.dumps(data), headers=headers)
        print(f"response:{response}")
        
        if response is not None and response.status_code == 200:
            try:
                response_data = response.json()
                print(f"response_data:{response_data}")
                image_url = response_data.get('response').get('image_url')
                
                if image_url:
                    print(f"图片URL: {image_url}")
                    return image_url
                else:
                    print("响应中未找到图片URL") 
                    return None
            except json.JSONDecodeError as e:
                print(f"JSON解析错误: {e}")
                return None
        else:
            print(f"请求失败，状态码: {response.status_code}")
            return None
    except requests.RequestException as e:
        print(f"请求错误: {e}")
        return None

    # return json.dumps({"response": response})


# 测试 print_response 函数
# 确保了print_response函数能够正确地打印出解析后的JSON数据，并且在调用函数后增加了异常处理逻辑来避免因解析错误而导致程序崩溃。


def get_prompt_response(prompt):
    # 这里假设 get_completion 函数从某个API获取数据并返回
    # 返回的结果应该是一个包含 'response' 键的字典

    # 假设这是从外部API获取的数据
    response = prompt

    # 正确的返回方式应该是这样的
    return json.dumps({"response": response})

def print_response(prompt):
    try:
        result = get_completion(prompt)
        print(f"result:{result}")
        parsed_result = json.loads(result)
        print(parsed_result['response'])
    except json.JSONDecodeError as e:
        print(f"JSON 解析错误: {e}")
        # 处理错误情况，例如打印原始返回值
        print("原始返回值:", result)

print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
# Out:
# 请求错误：HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# 请求错误: HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# result:None
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[13], line 69
#
#      66         # 处理错误情况，例如打印原始返回值
#
#      67         print("原始返回值:", result)
#
# ---> 69 print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
#
#
#
# Cell In[13], line 62, in print_response(prompt)
#
#      60     result = get_completion(prompt)
#
#      61     print(f"result:{result}")
#
# ---> 62     parsed_result = json.loads(result)
#
#      63     print(parsed_result['response'])
#
#      64 except json.JSONDecodeError as e:
#
#
#
# ...

# %%
import requests
import json
from pathlib import Path


try:
    response = requests.get('https://127.0.0.1:8080', timeout=10)  # 默认超时时间为 10 秒
except requests.exceptions.ConnectionError as e:
    print(f"请求错误：{e}")


def get_completion(image_path:str|Path, url='https://127.0.0.1:8080'):
    headers = {'Content-Type': 'application/json'}
    data = {"image_path": image_path}
    try:
        response = requests.get(url=url, data=json.dumps(data), headers=headers)
        print(f"response:{response}")
        
        if response is not None and response.status_code == 200:
            try:
                response_data = response.json()
                print(f"response_data:{response_data}")
                image_url = response_data.get('response').get('image_url')
                
                if image_url:
                    print(f"图片URL: {image_url}")
                    return image_url
                else:
                    print("响应中未找到图片URL") 
                    return None
            except json.JSONDecodeError as e:
                print(f"JSON解析错误: {e}")
                return None
        else:
            print(f"请求失败，状态码: {response.status_code}")
            return None
    except requests.RequestException as e:
        print(f"请求错误: {e}")
        return None

    # return json.dumps({"response": response})


# 测试 print_response 函数
# 确保了print_response函数能够正确地打印出解析后的JSON数据，并且在调用函数后增加了异常处理逻辑来避免因解析错误而导致程序崩溃。


def get_prompt_response(prompt):
    # 这里假设 get_completion 函数从某个API获取数据并返回
    # 返回的结果应该是一个包含 'response' 键的字典

    # 假设这是从外部API获取的数据
    response = prompt

    # 正确的返回方式应该是这样的
    return json.dumps({"response": response})

def print_response(prompt):
    try:
        result = get_completion(prompt)
        print(f"result:{result}")
        parsed_result = json.loads(result)
        print(parsed_result['response'])
    except json.JSONDecodeError as e:
        print(f"JSON 解析错误: {e}")
        # 处理错误情况，例如打印原始返回值
        print("原始返回值:", result)

print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
# Out:
# 请求错误：HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# 请求错误: HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# result:None
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[13], line 69
#
#      66         # 处理错误情况，例如打印原始返回值
#
#      67         print("原始返回值:", result)
#
# ---> 69 print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
#
#
#
# Cell In[13], line 62, in print_response(prompt)
#
#      60     result = get_completion(prompt)
#
#      61     print(f"result:{result}")
#
# ---> 62     parsed_result = json.loads(result)
#
#      63     print(parsed_result['response'])
#
#      64 except json.JSONDecodeError as e:
#
#
#
# ...

# %%
import requests
import json
from pathlib import Path


try:
    response = requests.get('https://127.0.0.1:8080', timeout=10)  # 默认超时时间为 10 秒
except requests.exceptions.ConnectionError as e:
    print(f"请求错误：{e}")


def get_completion(image_path:str|Path, url='https://127.0.0.1:8080'):
    headers = {'Content-Type': 'application/json'}
    data = {"image_path": image_path}
    try:
        response = requests.get(url=url, data=json.dumps(data), headers=headers)
        print(f"response:{response}")
        
        if response is not None and response.status_code == 200:
            try:
                response_data = response.json()
                print(f"response_data:{response_data}")
                image_url = response_data.get('response').get('image_url')
                
                if image_url:
                    print(f"图片URL: {image_url}")
                    return image_url
                else:
                    print("响应中未找到图片URL") 
                    return None
            except json.JSONDecodeError as e:
                print(f"JSON解析错误: {e}")
                return None
        else:
            print(f"请求失败，状态码: {response.status_code}")
            return None
    except requests.RequestException as e:
        print(f"请求错误: {e}")
        return None

    # return json.dumps({"response": response})


# 测试 print_response 函数
# 确保了print_response函数能够正确地打印出解析后的JSON数据，并且在调用函数后增加了异常处理逻辑来避免因解析错误而导致程序崩溃。


def get_prompt_response(prompt):
    # 这里假设 get_completion 函数从某个API获取数据并返回
    # 返回的结果应该是一个包含 'response' 键的字典

    # 假设这是从外部API获取的数据
    response = prompt

    # 正确的返回方式应该是这样的
    return json.dumps({"response": response})

def print_response(prompt):
    try:
        result = get_completion(prompt)
        print(f"result:{result}")
        parsed_result = json.loads(result)
        print(parsed_result['response'])
    except json.JSONDecodeError as e:
        print(f"JSON 解析错误: {e}")
        # 处理错误情况，例如打印原始返回值
        print("原始返回值:", result)

print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
# Out:
# 请求错误：HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# 请求错误: HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# result:None
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[13], line 69
#
#      66         # 处理错误情况，例如打印原始返回值
#
#      67         print("原始返回值:", result)
#
# ---> 69 print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
#
#
#
# Cell In[13], line 62, in print_response(prompt)
#
#      60     result = get_completion(prompt)
#
#      61     print(f"result:{result}")
#
# ---> 62     parsed_result = json.loads(result)
#
#      63     print(parsed_result['response'])
#
#      64 except json.JSONDecodeError as e:
#
#
#
# ...

# %%
import requests
import json
from pathlib import Path


try:
    response = requests.get('https://127.0.0.1:8080', timeout=10)  # 默认超时时间为 10 秒
except requests.exceptions.ConnectionError as e:
    print(f"请求错误：{e}")


def get_completion(image_path:str|Path, url='https://127.0.0.1:8080'):
    headers = {'Content-Type': 'application/json'}
    data = {"image_path": image_path}
    try:
        response = requests.get(url=url, data=json.dumps(data), headers=headers)
        print(f"response:{response}")
        
        if response is not None and response.status_code == 200:
            try:
                response_data = response.json()
                print(f"response_data:{response_data}")
                image_url = response_data.get('response').get('image_url')
                
                if image_url:
                    print(f"图片URL: {image_url}")
                    return image_url
                else:
                    print("响应中未找到图片URL") 
                    return None
            except json.JSONDecodeError as e:
                print(f"JSON解析错误: {e}")
                return None
        else:
            print(f"请求失败，状态码: {response.status_code}")
            return None
    except requests.RequestException as e:
        print(f"请求错误: {e}")
        return None

    # return json.dumps({"response": response})


# 测试 print_response 函数
# 确保了print_response函数能够正确地打印出解析后的JSON数据，并且在调用函数后增加了异常处理逻辑来避免因解析错误而导致程序崩溃。


def get_prompt_response(prompt):
    # 这里假设 get_completion 函数从某个API获取数据并返回
    # 返回的结果应该是一个包含 'response' 键的字典

    # 假设这是从外部API获取的数据
    response = prompt

    # 正确的返回方式应该是这样的
    return json.dumps({"response": response})

def print_response(prompt):
    try:
        result = get_completion(prompt)
        print(f"result:{result}")
        parsed_result = json.loads(result)
        print(parsed_result['response'])
    except json.JSONDecodeError as e:
        print(f"JSON 解析错误: {e}")
        # 处理错误情况，例如打印原始返回值
        print("原始返回值:", result)

print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
# Out:
# 请求错误：HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# 请求错误: HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# result:None
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[13], line 69
#
#      66         # 处理错误情况，例如打印原始返回值
#
#      67         print("原始返回值:", result)
#
# ---> 69 print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
#
#
#
# Cell In[13], line 62, in print_response(prompt)
#
#      60     result = get_completion(prompt)
#
#      61     print(f"result:{result}")
#
# ---> 62     parsed_result = json.loads(result)
#
#      63     print(parsed_result['response'])
#
#      64 except json.JSONDecodeError as e:
#
#
#
# ...

# %%
import requests
import json
from pathlib import Path


try:
    response = requests.get('https://127.0.0.1:8080', timeout=10)  # 默认超时时间为 10 秒
except requests.exceptions.ConnectionError as e:
    print(f"请求错误：{e}")


def get_completion(image_path:str|Path, url='https://127.0.0.1:8080'):
    headers = {'Content-Type': 'application/json'}
    data = {"image_path": image_path}
    try:
        response = requests.get(url=url, data=json.dumps(data), headers=headers)
        print(f"response:{response}")
        
        if response is not None and response.status_code == 200:
            try:
                response_data = response.json()
                print(f"response_data:{response_data}")
                image_url = response_data.get('response').get('image_url')
                
                if image_url:
                    print(f"图片URL: {image_url}")
                    return image_url
                else:
                    print("响应中未找到图片URL") 
                    return None
            except json.JSONDecodeError as e:
                print(f"JSON解析错误: {e}")
                return None
        else:
            print(f"请求失败，状态码: {response.status_code}")
            return None
    except requests.RequestException as e:
        print(f"请求错误: {e}")
        return None

    # return json.dumps({"response": response})


# 测试 print_response 函数
# 确保了print_response函数能够正确地打印出解析后的JSON数据，并且在调用函数后增加了异常处理逻辑来避免因解析错误而导致程序崩溃。


def get_prompt_response(prompt):
    # 这里假设 get_completion 函数从某个API获取数据并返回
    # 返回的结果应该是一个包含 'response' 键的字典

    # 假设这是从外部API获取的数据
    response = prompt

    # 正确的返回方式应该是这样的
    return json.dumps({"response": response})

def print_response(prompt):
    try:
        result = get_completion(prompt)
        print(f"result:{result}")
        parsed_result = json.loads(result)
        print(parsed_result['response'])
    except json.JSONDecodeError as e:
        print(f"JSON 解析错误: {e}")
        # 处理错误情况，例如打印原始返回值
        print("原始返回值:", result)

print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
# Out:
# 请求错误：HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# 请求错误: HTTPSConnectionPool(host='127.0.0.1', port=8080): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL] record layer failure (_ssl.c:1000)')))
# result:None
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[13], line 69
#
#      66         # 处理错误情况，例如打印原始返回值
#
#      67         print("原始返回值:", result)
#
# ---> 69 print_response('eg_api/SAM-Med2D/data_demo/images/amos_0507_31.png')
#
#
#
# Cell In[13], line 62, in print_response(prompt)
#
#      60     result = get_completion(prompt)
#
#      61     print(f"result:{result}")
#
# ---> 62     parsed_result = json.loads(result)
#
#      63     print(parsed_result['response'])
#
#      64 except json.JSONDecodeError as e:
#
#
#
# ...

# %%
import requests
import json
from pathlib import Path

def get_completion(image_path:str|Path, url='https://58.144.141.49'):
    headers = {'Content-Type': 'application/json'}
    data = {"image_path": image_path}
    try:
        response = requests.get(url=url, data=json.dumps(data), headers=headers)
        print(f"response:{response}")
        
        if response is not None and response.status_code == 200:
            try:
                response_data = response.json()
                print(f"response_data:{response_data}")
                image_url = response_data.get('response').get('image_url')
                
                if image_url:
                    print(f"图片URL: {image_url}")
                    return image_url
                else:
                    print("响应中未找到图片URL") 
                    return None
            except json.JSONDecodeError as e:
                print(f"JSON解析错误: {e}")
                return None
        else:
            print(f"请求失败，状态码: {response.status_code}")
            return None
    except requests.RequestException as e:
        print(f"请求错误: {e}")
        return None

    # return json.dumps({"response": response})


# 测试 print_response 函数
# 确保了print_response函数能够正确地打印出解析后的JSON数据，并且在调用函数后增加了异常处理逻辑来避免因解析错误而导致程序崩溃。


def get_prompt_response(prompt):
    # 这里假设 get_completion 函数从某个API获取数据并返回
    # 返回的结果应该是一个包含 'response' 键的字典

    # 假设这是从外部API获取的数据
    response = prompt

    # 正确的返回方式应该是这样的
    return json.dumps({"response": response})

def print_response(prompt):
    try:
        result = get_completion(prompt)
        print(f"result:{result}")
        parsed_result = json.loads(result)
        print(parsed_result['response'])
    except json.JSONDecodeError as e:
        print(f"JSON 解析错误: {e}")
        # 处理错误情况，例如打印原始返回值
        print("原始返回值:", result)

print_response('./SAM-Med2D/data_demo/images/amos_0507_31.png')
# Out:
# 请求错误: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# result:None
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[6], line 62
#
#      59         # 处理错误情况，例如打印原始返回值
#
#      60         print("原始返回值:", result)
#
# ---> 62 print_response('./SAM-Med2D/data_demo/images/amos_0507_31.png')
#
#
#
# Cell In[6], line 55, in print_response(prompt)
#
#      53     result = get_completion(prompt)
#
#      54     print(f"result:{result}")
#
# ---> 55     parsed_result = json.loads(result)
#
#      56     print(parsed_result['response'])
#
#      57 except json.JSONDecodeError as e:
#
#
#
# File ~/anaconda3/envs/api_test/lib/python3.12/json/__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#
#     337 else:
#
#     338     if not isinstance(s, (bytes, bytearray)):
#
# ...

# %%
import requests
import json
from pathlib import Path

def get_completion(image_path:str|Path, url='https://58.144.141.49'):
    headers = {'Content-Type': 'application/json'}
    data = {"image_path": image_path}
    try:
        response = requests.get(url=url, data=json.dumps(data), headers=headers)
        print(f"response:{response}")
        
        if response is not None and response.status_code == 200:
            try:
                response_data = response.json()
                print(f"response_data:{response_data}")
                image_url = response_data.get('response').get('image_url')
                
                if image_url:
                    print(f"图片URL: {image_url}")
                    return image_url
                else:
                    print("响应中未找到图片URL") 
                    return None
            except json.JSONDecodeError as e:
                print(f"JSON解析错误: {e}")
                return None
        else:
            print(f"请求失败，状态码: {response.status_code}")
            return None
    except requests.RequestException as e:
        print(f"请求错误: {e}")
        return None

    # return json.dumps({"response": response})


# 测试 print_response 函数
# 确保了print_response函数能够正确地打印出解析后的JSON数据，并且在调用函数后增加了异常处理逻辑来避免因解析错误而导致程序崩溃。


def get_prompt_response(prompt):
    # 这里假设 get_completion 函数从某个API获取数据并返回
    # 返回的结果应该是一个包含 'response' 键的字典

    # 假设这是从外部API获取的数据
    response = prompt

    # 正确的返回方式应该是这样的
    return json.dumps({"response": response})

def print_response(prompt):
    try:
        result = get_completion(prompt)
        print(f"result:{result}")
        parsed_result = json.loads(result)
        print(parsed_result['response'])
    except json.JSONDecodeError as e:
        print(f"JSON 解析错误: {e}")
        # 处理错误情况，例如打印原始返回值
        print("原始返回值:", result)

print_response('./SAM-Med2D/data_demo/images/amos_0507_31.png')
# Out:
# 请求错误: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# result:None
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[6], line 62
#
#      59         # 处理错误情况，例如打印原始返回值
#
#      60         print("原始返回值:", result)
#
# ---> 62 print_response('./SAM-Med2D/data_demo/images/amos_0507_31.png')
#
#
#
# Cell In[6], line 55, in print_response(prompt)
#
#      53     result = get_completion(prompt)
#
#      54     print(f"result:{result}")
#
# ---> 55     parsed_result = json.loads(result)
#
#      56     print(parsed_result['response'])
#
#      57 except json.JSONDecodeError as e:
#
#
#
# File ~/anaconda3/envs/api_test/lib/python3.12/json/__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#
#     337 else:
#
#     338     if not isinstance(s, (bytes, bytearray)):
#
# ...

# %%
import requests
import json
from pathlib import Path

def get_completion(image_path:str|Path, url='https://58.144.141.49'):
    headers = {'Content-Type': 'application/json'}
    data = {"image_path": image_path}
    try:
        response = requests.get(url=url, data=json.dumps(data), headers=headers)
        print(f"response:{response}")
        
        if response is not None and response.status_code == 200:
            try:
                response_data = response.json()
                print(f"response_data:{response_data}")
                image_url = response_data.get('response').get('image_url')
                
                if image_url:
                    print(f"图片URL: {image_url}")
                    return image_url
                else:
                    print("响应中未找到图片URL") 
                    return None
            except json.JSONDecodeError as e:
                print(f"JSON解析错误: {e}")
                return None
        else:
            print(f"请求失败，状态码: {response.status_code}")
            return None
    except requests.RequestException as e:
        print(f"请求错误: {e}")
        return None

    # return json.dumps({"response": response})


# 测试 print_response 函数
# 确保了print_response函数能够正确地打印出解析后的JSON数据，并且在调用函数后增加了异常处理逻辑来避免因解析错误而导致程序崩溃。


def get_prompt_response(prompt):
    # 这里假设 get_completion 函数从某个API获取数据并返回
    # 返回的结果应该是一个包含 'response' 键的字典

    # 假设这是从外部API获取的数据
    response = prompt

    # 正确的返回方式应该是这样的
    return json.dumps({"response": response})

def print_response(prompt):
    try:
        result = get_completion(prompt)
        print(f"result:{result}")
        parsed_result = json.loads(result)
        print(parsed_result['response'])
    except json.JSONDecodeError as e:
        print(f"JSON 解析错误: {e}")
        # 处理错误情况，例如打印原始返回值
        print("原始返回值:", result)

print_response('./SAM-Med2D/data_demo/images/amos_0507_31.png')
# Out:
# 请求错误: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# result:None
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[6], line 62
#
#      59         # 处理错误情况，例如打印原始返回值
#
#      60         print("原始返回值:", result)
#
# ---> 62 print_response('./SAM-Med2D/data_demo/images/amos_0507_31.png')
#
#
#
# Cell In[6], line 55, in print_response(prompt)
#
#      53     result = get_completion(prompt)
#
#      54     print(f"result:{result}")
#
# ---> 55     parsed_result = json.loads(result)
#
#      56     print(parsed_result['response'])
#
#      57 except json.JSONDecodeError as e:
#
#
#
# File ~/anaconda3/envs/api_test/lib/python3.12/json/__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#
#     337 else:
#
#     338     if not isinstance(s, (bytes, bytearray)):
#
# ...

# %%
import subprocess

args_env = ["conda","activate","api_test"]
subprocess.run(args_env)

# 将onnx提前导出到文件夹./SAM_Med_2D/onnx_model文件夹中，使用 SAM_Med_2D在main.py中定义的args直接运行
args = ["python3", "./api.py",
        "--encoder_model", "./SAM-Med2D/onnx_model/sam-med2d_b.encoder.onnx",
        "--decoder_model", "./SAM-Med2D/onnx_model/sam-med2d_b.decoder.onnx"]

result = subprocess.run(args)

print(result)

# %%
import subprocess
args_end = ["http-server", "stop"]
subprocess.run(args_end)
